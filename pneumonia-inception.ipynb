# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import os
import cv2
from glob import glob
import seaborn as sns
import matplotlib.pyplot as plt
import random
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import RMSprop,Adam
from sklearn.model_selection import train_test_split
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.6.4

# %%
BASE_DIR=('../input/chest-xray-pneumonia/chest_xray/')
train_dir=os.path.join(BASE_DIR,'train/')
val_dir=os.path.join(BASE_DIR,'val/')
test_dir=os.path.join(BASE_DIR,'test/')

print('Number of images in training set = ',str(len(glob(train_dir+'*/*'))))
print('Number of images in validation set = ',str(len(glob(val_dir+'*/*'))))
print('Number of images in testing set = ',str(len(glob(test_dir+'*/*'))))
# Out:
# Number of images in training set =  5216
# Number of images in validation set =  16
# Number of images in testing set =  624

# %%
training_images = tf.io.gfile.glob('../input/chest-xray-pneumonia/chest_xray/train/*/*')
validation_images = tf.io.gfile.glob('../input/chest-xray-pneumonia/chest_xray/val/*/*')


total_files = training_images
total_files.extend(validation_images)
print(f'Total number of images : training_images + validation_images = {len(total_files)}\n')

#spliting 80:20
train_images, val_images = train_test_split(total_files, test_size = 0.2)
print(f'After division of 80:20')
print(f'Total number of training images = {len(train_images)}')
print(f'Total number of validation images = {len(val_images)}')
# Out:
# Total number of images : training_images + validation_images = 5232
#
# After division of 80:20
# Total number of training images = 4185
# Total number of validation images = 1047

# %%
tf.io.gfile.makedirs('/kaggle/working/val_dataset/NORMAL/')
tf.io.gfile.makedirs('/kaggle/working/val_dataset/PNEUMONIA/')
tf.io.gfile.makedirs('/kaggle/working/train_dataset/NORMAL/')
tf.io.gfile.makedirs('/kaggle/working/train_dataset/PNEUMONIA/')

# %%
for ele in train_images:
    parts_of_path = ele.split('/')

    if 'PNEUMONIA' == parts_of_path[-2]:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/train_dataset/PNEUMONIA/' +  parts_of_path[-1])
    else:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/train_dataset/NORMAL/' +  parts_of_path[-1])

# %%
for ele in val_images:
    parts_of_path = ele.split('/')

    if 'PNEUMONIA' == parts_of_path[-2]:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/val_dataset/PNEUMONIA/' +  parts_of_path[-1])
    else:
        tf.io.gfile.copy(src = ele, dst = '/kaggle/working/val_dataset/NORMAL/' +  parts_of_path[-1])

# %%
train_dir='/kaggle/working/train_dataset/'
val_dir='/kaggle/working/val_dataset/'
test_dir='../input/chest-xray-pneumonia/chest_xray/test/'

train_normal_dir='/kaggle/working/train_dataset/NORMAL'
train_pneumonia_dir='/kaggle/working/train_dataset/PNEUMONIA'
val_normal_dir='/kaggle/working/val_dataset/NORMAL'
val_pneumonia_dir='/kaggle/working/val_dataset/PNEUMONIA'

# %%
train_normal_fnames=os.listdir(train_normal_dir)
train_pneumonia_fnames=os.listdir(train_pneumonia_dir)

print(train_normal_fnames[:10])
print(train_pneumonia_fnames[:10])
# Out:
# ['NORMAL2-IM-1168-0001.jpeg', 'NORMAL2-IM-1163-0001.jpeg', 'NORMAL2-IM-0962-0001.jpeg', 'IM-0145-0001.jpeg', 'NORMAL2-IM-0599-0001.jpeg', 'NORMAL2-IM-0725-0001.jpeg', 'IM-0577-0001.jpeg', 'IM-0491-0001-0002.jpeg', 'NORMAL2-IM-0896-0001.jpeg', 'IM-0170-0001.jpeg']
# ['person1012_bacteria_2943.jpeg', 'person961_bacteria_2886.jpeg', 'person408_bacteria_1823.jpeg', 'person68_bacteria_336.jpeg', 'person1170_virus_1970.jpeg', 'person1268_bacteria_3227.jpeg', 'person274_bacteria_1289.jpeg', 'person38_bacteria_190.jpeg', 'person1463_virus_2516.jpeg', 'person1333_bacteria_3385.jpeg']

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

# %%
train_datagen=ImageDataGenerator(rescale=1.0/255,
                                 rotation_range=30,
                                 width_shift_range=0.2,
                                 height_shift_range=0.2,
                                 zoom_range=0.2,
                                 )

val_datagen=ImageDataGenerator(rescale=1.0/255)

test_datagen=ImageDataGenerator(rescale=1.0/255)

train_generator=train_datagen.flow_from_directory(train_dir,target_size=(180,180),batch_size=128,class_mode='binary')

val_generator=val_datagen.flow_from_directory(val_dir,target_size=(180,180),batch_size=128,class_mode='binary')

test_generator=test_datagen.flow_from_directory(test_dir,target_size=(180,180),batch_size=128,class_mode='binary')
# Out:
# Found 4185 images belonging to 2 classes.
# Found 1047 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
pretrained_model3=InceptionV3(input_shape=(180,180,3),
                             include_top=False,
                             weights='imagenet')
#freazing the trained layers
for layers in pretrained_model3.layers:
    layers.trainable=False
# Out:
# 2022-09-26 08:04:30.413243: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:30.508096: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:30.508993: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:30.510795: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-09-26 08:04:30.511090: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:30.511939: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:30.512658: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:32.768541: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:32.769474: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:32.770129: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-09-26 08:04:32.770711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
last_layer=pretrained_model3.get_layer('mixed10')
last_output = last_layer.output

# %%
x=tf.keras.layers.Flatten()(last_output)
x=tf.keras.layers.Dense(1024,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(256,activation='relu')(x)
x=tf.keras.layers.Dropout(0.2)(x)
x=tf.keras.layers.Dense(1,activation='sigmoid')(x)

model=tf.keras.Model(pretrained_model3.input,x)

model.compile(optimizer=RMSprop(lr=0.001),
              loss='binary_crossentropy',
               metrics=['accuracy','Precision','Recall'])
# model.summary()
# Out:
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
history3=model.fit(train_generator,validation_data=val_generator,epochs=30,verbose=2)
# Out:
# 2022-09-26 08:04:38.159833: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/30
# 2022-09-26 08:04:45.791124: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 33/33 - 94s - loss: 15.5506 - accuracy: 0.7180 - precision: 0.8046 - recall: 0.8171 - val_loss: 0.5618 - val_accuracy: 0.7125 - val_precision: 0.9880 - val_recall: 0.6256
# Epoch 2/30
# 33/33 - 82s - loss: 0.9887 - accuracy: 0.7685 - precision: 0.8416 - recall: 0.8462 - val_loss: 0.4380 - val_accuracy: 0.9121 - val_precision: 0.9383 - val_recall: 0.9454
# Epoch 3/30
# 33/33 - 82s - loss: 0.5840 - accuracy: 0.8146 - precision: 0.8710 - recall: 0.8795 - val_loss: 0.4278 - val_accuracy: 0.8262 - val_precision: 0.9840 - val_recall: 0.7817
# Epoch 4/30
# 33/33 - 82s - loss: 0.3736 - accuracy: 0.8533 - precision: 0.8980 - recall: 0.9044 - val_loss: 0.2756 - val_accuracy: 0.8978 - val_precision: 0.8955 - val_recall: 0.9784
# Epoch 5/30
# 33/33 - 82s - loss: 0.4307 - accuracy: 0.8550 - precision: 0.8974 - recall: 0.9076 - val_loss: 0.3152 - val_accuracy: 0.8052 - val_precision: 0.7955 - val_recall: 0.9975
# Epoch 6/30
# 33/33 - 82s - loss: 0.4082 - accuracy: 0.8583 - precision: 0.8999 - recall: 0.9095 - val_loss: 0.2531 - val_accuracy: 0.9016 - val_precision: 0.9790 - val_recall: 0.8883
# Epoch 7/30
# 33/33 - 82s - loss: 0.3223 - accuracy: 0.8803 - precision: 0.9187 - recall: 0.9195 - val_loss: 0.3333 - val_accuracy: 0.9007 - val_precision: 0.9831 - val_recall: 0.8832
# Epoch 8/30
# 33/33 - 91s - loss: 0.3409 - accuracy: 0.8791 - precision: 0.9161 - recall: 0.9208 - val_loss: 0.2245 - val_accuracy: 0.9351 - val_precision: 0.9592 - val_recall: 0.9543
# Epoch 9/30
# 33/33 - 81s - loss: 0.2961 - accuracy: 0.8970 - precision: 0.9283 - recall: 0.9328 - val_loss: 0.1988 - val_accuracy: 0.9284 - val_precision: 0.9396 - val_recall: 0.9670
# Epoch 10/30
# 33/33 - 82s - loss: 0.2786 - accuracy: 0.9039 - precision: 0.9379 - recall: 0.9318 - val_loss: 0.1742 - val_accuracy: 0.9417 - val_precision: 0.9584 - val_recall: 0.9645
# Epoch 11/30
# 33/33 - 82s - loss: 0.2979 - accuracy: 0.9068 - precision: 0.9347 - recall: 0.9396 - val_loss: 0.1770 - val_accuracy: 0.9303 - val_precision: 0.9864 - val_recall: 0.9201
# Epoch 12/30
# 33/33 - 81s - loss: 0.2528 - accuracy: 0.9039 - precision: 0.9390 - recall: 0.9305 - val_loss: 0.3334 - val_accuracy: 0.8940 - val_precision: 0.9927 - val_recall: 0.8655
# Epoch 13/30
# 33/33 - 83s - loss: 0.2694 - accuracy: 0.9039 - precision: 0.9345 - recall: 0.9357 - val_loss: 0.3790 - val_accuracy: 0.8472 - val_precision: 0.9968 - val_recall: 0.7995
# Epoch 14/30
# 33/33 - 83s - loss: 0.2628 - accuracy: 0.9070 - precision: 0.9362 - recall: 0.9383 - val_loss: 0.1523 - val_accuracy: 0.9436 - val_precision: 0.9740 - val_recall: 0.9505
# Epoch 15/30
# 33/33 - 83s - loss: 0.3695 - accuracy: 0.9008 - precision: 0.9382 - recall: 0.9270 - val_loss: 0.1868 - val_accuracy: 0.9351 - val_precision: 0.9423 - val_recall: 0.9734
# Epoch 16/30
# 33/33 - 83s - loss: 0.2268 - accuracy: 0.9233 - precision: 0.9492 - recall: 0.9470 - val_loss: 0.2395 - val_accuracy: 0.9169 - val_precision: 0.9888 - val_recall: 0.8997
# Epoch 17/30
# 33/33 - 82s - loss: 0.2574 - accuracy: 0.9142 - precision: 0.9421 - recall: 0.9418 - val_loss: 0.1505 - val_accuracy: 0.9417 - val_precision: 0.9866 - val_recall: 0.9353
# Epoch 18/30
# 33/33 - 83s - loss: 0.2406 - accuracy: 0.9192 - precision: 0.9448 - recall: 0.9460 - val_loss: 0.1734 - val_accuracy: 0.9456 - val_precision: 0.9540 - val_recall: 0.9746
# Epoch 19/30
# 33/33 - 83s - loss: 0.2468 - accuracy: 0.9140 - precision: 0.9407 - recall: 0.9431 - val_loss: 0.2770 - val_accuracy: 0.8672 - val_precision: 0.9969 - val_recall: 0.8261
# Epoch 20/30
# 33/33 - 83s - loss: 0.2367 - accuracy: 0.9180 - precision: 0.9465 - recall: 0.9425 - val_loss: 0.1432 - val_accuracy: 0.9465 - val_precision: 0.9716 - val_recall: 0.9569
# Epoch 21/30
# 33/33 - 82s - loss: 0.2453 - accuracy: 0.9157 - precision: 0.9451 - recall: 0.9405 - val_loss: 0.1479 - val_accuracy: 0.9484 - val_precision: 0.9842 - val_recall: 0.9467
# Epoch 22/30
# 33/33 - 83s - loss: 0.2317 - accuracy: 0.9295 - precision: 0.9490 - recall: 0.9561 - val_loss: 0.2098 - val_accuracy: 0.9179 - val_precision: 0.9916 - val_recall: 0.8985
# Epoch 23/30
# 33/33 - 83s - loss: 0.2381 - accuracy: 0.9173 - precision: 0.9450 - recall: 0.9431 - val_loss: 0.2808 - val_accuracy: 0.9093 - val_precision: 0.9915 - val_recall: 0.8871
# Epoch 24/30
# 33/33 - 83s - loss: 0.2390 - accuracy: 0.9173 - precision: 0.9458 - recall: 0.9422 - val_loss: 0.2376 - val_accuracy: 0.9274 - val_precision: 0.9890 - val_recall: 0.9137
# Epoch 25/30
# 33/33 - 82s - loss: 0.2111 - accuracy: 0.9228 - precision: 0.9477 - recall: 0.9480 - val_loss: 0.1306 - val_accuracy: 0.9532 - val_precision: 0.9648 - val_recall: 0.9734
# Epoch 26/30
# 33/33 - 83s - loss: 0.2271 - accuracy: 0.9290 - precision: 0.9522 - recall: 0.9519 - val_loss: 0.1297 - val_accuracy: 0.9532 - val_precision: 0.9830 - val_recall: 0.9543
# Epoch 27/30
# 33/33 - 83s - loss: 0.2000 - accuracy: 0.9228 - precision: 0.9480 - recall: 0.9477 - val_loss: 0.1630 - val_accuracy: 0.9360 - val_precision: 0.9905 - val_recall: 0.9239
# Epoch 28/30
# 33/33 - 82s - loss: 0.2102 - accuracy: 0.9266 - precision: 0.9556 - recall: 0.9447 - val_loss: 0.1722 - val_accuracy: 0.9456 - val_precision: 0.9841 - val_recall: 0.9429
# Epoch 29/30
# 33/33 - 83s - loss: 0.2600 - accuracy: 0.9274 - precision: 0.9532 - recall: 0.9483 - val_loss: 0.1506 - val_accuracy: 0.9465 - val_precision: 0.9854 - val_recall: 0.9429
# Epoch 30/30
# 33/33 - 82s - loss: 0.2106 - accuracy: 0.9305 - precision: 0.9528 - recall: 0.9532 - val_loss: 0.1559 - val_accuracy: 0.9456 - val_precision: 0.9854 - val_recall: 0.9416

# %%
acc3 = history3.history['accuracy']
val_acc3 = history3.history['val_accuracy']

train_precision3=history3.history['precision']
val_precision3=history3.history['val_precision']

train_recall3=history3.history['recall']
val_recall3=history3.history['val_recall']

loss3 = history3.history['loss']
val_loss3 = history3.history['val_loss']
epochs = range(len(acc3))

plt.plot(epochs, acc3, 'r', label='Training accuracy')
plt.plot(epochs, val_acc3, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.show()

plt.plot(epochs, train_precision3, 'r', label='Training precision')
plt.plot(epochs, val_precision3, 'b', label='Validation precision')
plt.title('Training and validation precision')
plt.legend()
plt.show()

plt.plot(epochs, train_recall3, 'r', label='Training recall')
plt.plot(epochs, val_recall3, 'b', label='Validation recall')
plt.title('Training and validation recall')
plt.legend()
plt.show()

plt.plot(epochs, loss3, 'r', label='Training Loss')
plt.plot(epochs, val_loss3, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
model.save('inception.h5')

# %%
import pickle
filename = 'inception.pkl'
pickle.dump(model, open(filename, 'wb'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_17/322528093.py in <module>
#       1 import pickle
#       2 filename = 'inception.pkl'
# ----> 3 pickle.dump(model, open(filename, 'wb'))
#
# TypeError: can't pickle weakref objects
